# %%
#This function returns the best performing stock names and their percentage changes in a given period. 
#Daily: input 1; Weekly: input 2; Monthly: input 3; Quarterly: input 4; Year-to-Date: input 5

def get_best_performers(x=1):
    import requests
    from bs4 import BeautifulSoup
    import pandas as pd
    from wordcloud import WordCloud, STOPWORDS
    import matplotlib.pyplot as plt
    
    output_list = []
    stock_list = []
    pct_list = []
    freq_list=[]
    new_list=[]
    cloud_list=[]
    
    if x==1:
        url = "https://csimarket.com/markets/Stocks.php?days=yday&=#tablecomp"
    elif x==2:
        url = "https://csimarket.com/markets/Stocks.php?days=week&=#tablecomp"
    elif x==3:
        url = "https://csimarket.com/markets/Stocks.php?days=month&=#tablecomp"
    elif x==4:
        url = "https://csimarket.com/markets/Stocks.php?days=quarter&=#tablecomp"
    elif x==5:
        url = "https://csimarket.com/markets/Stocks.php?days=ytd&=#tablecomp"
    else:
        return 'Wrong input!'
    
    results_page = requests.get(url)
    soup = BeautifulSoup(results_page.content,'lxml')
    all_tags = soup.find_all('td', class_='lk')
    for tag in all_tags:
        output_list.append(tag.get_text().replace(',','').replace('\xa0','').replace(' ',''))
    for i in range(0,40):
        if i % 2 == 0:
            stock_list.append(output_list[i])
        if i % 2 == 1:
            pct_list.append((output_list[i]))
    
    df = pd.DataFrame(pct_list, stock_list)    
    if x==1:
        df.index.name = 'Daily Best Performing Stocks'
    elif x==2:
        df.index.name = 'Weekly Best Performing Stocks'
    elif x==3:
        df.index.name = 'Monthly Best Performing Stocks'
    elif x==4:
        df.index.name = 'Quarterly Best Performing Stocks'
    elif x==5:
        df.index.name = 'Year-to-Date Best Performing Stocks'
    else:
        return None
    df.columns = ['pct_change']
    
    for i in pct_list:
        x=round(float(i.replace('%','')))
        freq_list.append(x)
    new_list=stock_list+freq_list
    for i in range(0,20):
        for x in range(0,new_list[i+20]):
            cloud_list.append(new_list[i])
    
    stock_string=(" ").join(cloud_list)
    wordcloud = WordCloud(width = 1600, height = 800, relative_scaling=0.5, max_words = 1000, max_font_size=60, min_font_size=10, 
                          background_color="white", repeat=True, margin=50, random_state=3).generate(stock_string)
    plt.figure(figsize=(20,10))
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.savefig("wordcloud"+".png", bbox_inches='tight')
    plt.show()
    plt.close()
    
    return df

    
get_best_performers(1)
# Out:
#                                   pct_change
# Daily Best Performing Stocks
# NorstraEnergyInc                     900.00%
# PetrosonicEnergyInc.                 200.00%
# WalterEnergyInc.                     166.67%
# PositiveidCorp                       100.00%
# SpoGlobalInc                         100.00%
# VetOnlineSupplyInc                   100.00%
# NorthBayResourcesInc                 100.00%
# AmericanGraphiteTechnologiesInc.      77.27%
# OnelifeTechnologiesCorp               75.00%
# FutureHealthcareOfAmerica             70.00%
# HarrisonVickers&WatermanInc           60.00%
# ProtokinetixInc.                      60.00%
# TelInstrumentElectronicsCorp          57.96%
# Plastic2oilInc.                       57.78%
# MobilesmithInc.                       54.17%
# DominovasEnergyCorp                   50.00%
# LingerieFightingChampionshipsInc.     50.00%
# PulseBeverageCorp                     50.00%
# AllAmericanGoldCorp.                  50.00%
# TxHoldingsInc.                        47.54%

# %%
def get_all_indexes():
    import requests
    from bs4 import BeautifulSoup
    import pandas as pd
    
    index_list = []
    last_list = []
    
    url = "https://markets.wsj.com/"
    results_page = requests.get(url)
    soup = BeautifulSoup(results_page.content,'lxml')
    index_tags = soup.find_all('td', class_='firstCol')
    last_tags = soup.find_all('td', class_='dataCol dataColCenter')
    
    for tag in index_tags:
        index_list.append(tag.get_text().replace('\n',''))
    for tag in last_tags:
        last_list.append(tag.get_text())
    index_list = index_list[23:42]

    df = pd.DataFrame(last_list, index_list)
    df.index.name = 'Major U.S. Stock Indexes'
    df.columns = ['Last']
    
    return df

get_all_indexes()
# Out:
#                                Last
# Major U.S. Stock Indexes
# DJIA                       25538.46
# DJ Transportation Average  10820.20
# DJ Utility Average           741.92
# DJ Total Stock Market      28418.59
# Barron's 400                 687.81
# Nasdaq Composite            7330.54
# Nasdaq 100                  6949.01
# S&P 500                     2760.17
# S&P MidCap 400              1878.65
# S&P SmallCap 600             962.95
# Russell 2000                1533.27
# NYSE Composite             12457.55
# NYSE Arca Biotech           4755.55
# NYSE Arca Pharma             609.15
# KBW Bank                     101.57
# PHLX Gold/Silver              64.46
# PHLX Oil Service             104.74
# PHLX Semiconductor          1239.60
# CBOE Volatility               18.07

# %%
def get_currency_table():
    import requests
    from bs4 import BeautifulSoup
    import pandas as pd
    
    cu_list = []
    url = "https://markets.on.nytimes.com/research/markets/currencies/currencies.asp"
    results_page = requests.get(url)
    soup = BeautifulSoup(results_page.content,'lxml')
    cu_tags = soup.find_all('td')
    
    for tag in cu_tags:
        cu_list.append(tag.get_text())
    cu_list=cu_list[60:90]
    df = pd.DataFrame(cu_list[1::6], columns=['Dollar'])
    df.rename(index={0:cu_list[::6][0],1:cu_list[::6][1],2:cu_list[::6][2],3:cu_list[::6][3],4:cu_list[::6][4]}, inplace=True)
    df['Euro'] = cu_list[2::6]
    df['Pound'] = cu_list[3::6]
    df['Yen'] = cu_list[4::6]
    df['Yuan'] = cu_list[5::6]
    
    return df

get_currency_table()
# Out:
#                Dollar    Euro   Pound     Yen     Yuan
# Dollar U.S.        --  1.1315  1.2757  0.0088   0.1436
# Euro Europe    0.8835      --   1.127  0.0078   0.1268
# Pound Britain  0.7836  0.8866      --  0.0069   0.1125
# Yen Japan      113.46  128.38  144.74      --  16.2896
# Yuan China     6.9558  7.8705  8.8735  0.0613       --

# %%
def get_currency_table():
    import requests
    from bs4 import BeautifulSoup
    import pandas as pd
    cu_list = []
    url = "https://markets.on.nytimes.com/research/markets/currencies/currencies.asp"
    results_page = requests.get(url)
    soup = BeautifulSoup(results_page.content,'lxml')
    cu_tags = soup.find_all('td')
    for tag in cu_tags:
        cu_list.append(tag.get_text())
    cu_list=cu_list[60:90]
    cu_list
    l1 = cu_list[::6]
    l2 = cu_list[1::6]
    l3 = cu_list[2::6]
    l4 = cu_list[3::6]
    l5 = cu_list[4::6]
    l6 = cu_list[5::6]
    df = pd.DataFrame(l2, columns=['Dollar'])
    df.rename(index={0:l1[0],1:l1[1],2:l1[2],3:l1[3],4:l1[4]}, inplace=True)
    df['Euro'] = l3
    df['Pound'] = l4
    df['Yen'] = l5
    df['Yuan'] = l6
    return df
get_currency_table()

# %%
#Daily: input 1; Weekly: input 2; Monthly: input 3; Quarterly: input 4; Year-to-Date: input 5

def get_best_performers(x=1):
    import requests
    from bs4 import BeautifulSoup
    import pandas as pd
    from wordcloud import WordCloud, STOPWORDS
    import matplotlib.pyplot as plt
    
    output_list = []
    stock_list = []
    pct_list = []
    
    if x==1:
        url = "https://csimarket.com/markets/Stocks.php?days=yday&=#tablecomp"
    elif x==2:
        url = "https://csimarket.com/markets/Stocks.php?days=week&=#tablecomp"
    elif x==3:
        url = "https://csimarket.com/markets/Stocks.php?days=month&=#tablecomp"
    elif x==4:
        url = "https://csimarket.com/markets/Stocks.php?days=quarter&=#tablecomp"
    elif x==5:
        url = "https://csimarket.com/markets/Stocks.php?days=ytd&=#tablecomp"
    else:
        return 'Wrong input!'
    
    results_page = requests.get(url)
    soup = BeautifulSoup(results_page.content,'lxml')
    all_tags = soup.find_all('td', class_='lk')
    for tag in all_tags:
        output_list.append(tag.get_text().replace(',','').replace('\xa0','').replace(' ',''))
    for i in range(0,40):
        if i % 2 == 0:
            stock_list.append(output_list[i])
        if i % 2 == 1:
            pct_list.append((output_list[i]))
    
    df = pd.DataFrame(pct_list, stock_list)    
    if x==1:
        df.index.name = 'Daily Best Performing Stocks'
    elif x==2:
        df.index.name = 'Weekly Best Performing Stocks'
    elif x==3:
        df.index.name = 'Monthly Best Performing Stocks'
    elif x==4:
        df.index.name = 'Quarterly Best Performing Stocks'
    elif x==5:
        df.index.name = 'Year-to-Date Best Performing Stocks'
    else:
        return None
    df.columns = ['pct_change']
    
    stock_string=(" ").join(stock_list)
    wordcloud = WordCloud(width = 600, height = 600, max_font_size=50, min_font_size=10, background_color="white").generate(stock_string)
    plt.figure(figsize=(15,8))
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.savefig("wordcloud"+".png", bbox_inches='tight')
    plt.show()
    plt.close()
    
    return df

    
get_best_performers(1)

# %%
output_list = []
stock_list = []
pct_list = []
url = "https://csimarket.com/markets/Stocks.php?days=yday&=#tablecomp"
results_page = requests.get(url)
soup = BeautifulSoup(results_page.content,'lxml')
all_tags = soup.find_all('td', class_='lk')
for tag in all_tags:
    output_list.append(tag.get_text().replace(',','').replace('\xa0','').replace(' ',''))
for i in range(0,40):
    if i % 2 == 0:
        stock_list.append(output_list[i])
    if i % 2 == 1:
        pct_list.append((output_list[i]))
df = pd.DataFrame(pct_list, stock_list)
df.columns = ['pct_change']
df

freq_list=[]
new_list=[]
cloud_list=[]

for i in pct_list:
    x=round(float(i.replace('%','')))
    freq_list.append(x)
new_list=stock_list+freq_list
for i in range(0,20):
    for x in range(0,new_list[i+20]):
        cloud_list.append(new_list[i])

stock_string=(" ").join(cloud_list)
wordcloud = WordCloud(width = 1600, height = 800, relative_scaling=0.5, max_words = 1000, max_font_size=60, min_font_size=10, 
                      background_color="white", repeat=True, margin=10, random_state=3).generate(stock_string)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.savefig("wordcloud"+".png", bbox_inches='tight')
plt.show()
plt.close()
df

# %%
<span data-ng-if="::isLink(key, row)"> <a target="_self" data-ng-class="setTriggeredClass(row)" data-ng-href="/futures/quotes/ZWH19" data-ng-bind="cell" href="/futures/quotes/ZWH19">ZWH19</a> </span>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

name=[]
name1=[]
price=[]
change=[]
pctchange=[]
price1=[]
price2=[]

pattern = r'\d+.\d+'
url = "https://www.marketwatch.com/tools/futures"
results_page = requests.get(url)
soup = BeautifulSoup(results_page.content,'lxml')
l1_tags = soup.find_all('td',class_='name')
l2_tags = soup.find_all('td',class_='price')
l3_tags = soup.find_all('td',class_='bgChange')
l4_tags = soup.find_all('td',class_='bgPercentChange')

for tag in l1_tags:
    name.append(tag.get_text())   
for string in name:
    l = string.split('/')
    if 'quotes' in l:
        for i in range(0, l.index('quotes')):
            name1.append(l[i])
    else:
        name1.append(string)

for tag in l2_tags:
    price.append(tag.get_text())
for val in price:
    price1.append(re.findall(pattern, val))
for i in range(0, len(price1)):
    price2.append(price1[i][0])
    
for tag in l3_tags:
    change.append(tag.get_text())

for tag in l4_tags:
    pctchange.append(tag.get_text())
# Out:
# ['10-Year Euro Bund',
#  '10-Year Swapnote',
#  '10-Year Treasury Notes',
#  '1-Month Libor',
#  '2-Year Euro Schatz',
#  '2-Year Treasury Notes',
#  '30-Day Federal Funds',
#  '30-Year Treasury Notes',
#  '3-Month Euribor',
#  '3-Month Euro Dollar',
#  '3-Month Euroswiss',
#  '5-Year Euro Bob',
#  '5-Year Swapnote',
#  '5-Year Treasury Notes',
#  'AUD/USD (FrontMonth)',
#  'Australian Dollar Futures',
#  'BIST 30 (FrontMonth)',
#  'Bitcoin Futures Cboe',
#  'Bitcoin Futures CME',
#  'BOVESPA (FrontMonth)',
#  'Brent Crude - Continuous (ICE EU)',
#  'Brent crude - Open Interest',
#  'British Pound Futures',
#  'CAC Futures',
#  'CAD/USD (FrontMonth)',
#  'Canadian Bankers',
#  'Canadian Dollar Futures',
#  'CBOE VIX Index (FrontMonth)',
#  'CBOT Mini Dow USD 5 (IndexFuture)',
#  'CHF',
#  'USD (FrontMonth)',
#  'Coal',
#  'Cocoa',
#  'Cocoa - Continuous (ICE US)',
#  'Coffee',
#  'Coffee (FrontMonth)',
#  'Copper',
#  'Copper - Continuous (COMEX)',
#  'Corn',
#  'Corn - Continuous (CBOT)',
#  'Cotton',
#  'Cotton - Continuous (ICE US)',
#  'Crude Oil - Continuous (NYMEX)',
#  'Crude Oil - Electronic',
#  'Crude Oil - WTI',
#  'DAX Futures',
#  'Dow Jones Industrial futures',
#  'Ethanol',
#  'EUR/USD (FrontMonth)',
#  'Euro Futures',
#  'Euro STOXX 50 Futures',
#  'Feeder cattle',
#  'Feeder Cattle - Continuous (CME)',
#  'Finex USD Index (FrontMonth)',
#  'FTSE Futures',
#  'Gas Oil',
#  'GBP/USD (FrontMonth)',
#  'Gold',
#  'Gold - Continuous (COMEX)',
#  'Hang Seng Futures',
#  'Heating oil',
#  'Heating Oil - Continuous (NYMEX)',
#  'ICE UK Gas Future - Monthly',
#  'ICE UK Gas Future - Seasonal',
#  'Japanese Yen Futures',
#  'JPY/USD (FrontMonth)',
#  'Kohle - monatlich',
#  'Lean Hogs',
#  'Lean Hogs - Continuous (CME)',
#  'Live Cattle',
#  'Live Cattle - Continuous (CME)',
#  'London Cocoa',
#  'Long Guilt',
#  'Lumber',
#  'Lumber - Continuous (CME)',
#  'MIB Futures',
#  'MXN/USD (FrontMonth)',
#  'NASDAQ 100 E-Mini (IndexFuture)',
#  'Nasdaq 100 futures',
#  'Natural Gas',
#  'Natural Gas - Continuous (NYMEX)',
#  'Nikkei Futures',
#  'Orange juice',
#  'Orange Juice - Continuous (ICE US)',
#  'Palladium',
#  'Palladium - Continuous (NYMEX)',
#  'Platinum',
#  'Platinum - Continuous (NYMEX)',
#  'Robusta Coffee',
#  'Russell 1000 Mini (FrontMonth)',
#  'Russell 2000 (FrontMonth)',
#  'S&P E-Mini 500 Idx (IndexFuture)',
#  'Short Sterling',
#  'Silver',
#  'Silver - Continuous (COMEX)',
#  'Soybean Meal',
#  'Soybean Oil',
#  'Soybeans',
#  'Soybeans - Continuous (CBOT)',
#  'SP 500 futures',
#  'Steel - Hot-Rolled Coil',
#  'STOXX 600 Futures',
#  'STOXX Europe 50 Futures',
#  'Sugar',
#  'Sugar - Continuous (ICE US)',
#  'Swiss Franc Futures',
#  'Swiss Market Futures',
#  'TecDAX Futures',
#  'Unleaded gasoline',
#  'Unleaded Gasoline - Continuous (NYMEX)',
#  'US Dollar Index Futures',
#  'USD 10Y Treasury N (FrontMonth)',
#  'USD 2Y Treasury N (FrontMonth)',
#  'Wheat',
#  'Wheat - Continuous (CBOT)',
#  'White Sugar',
#  'WTI Crude',
#  'WTI Crude - Continuous (ICE EU)']

# %%
lis=[]
string = '5-Year Swapnote/quotes/zigman/114955626/realtime'
l = string.split('/')
if 'quotes' in l:
    for i in range(0, l.index('quotes')):
        lis.append(l[i])
else:
    lis.append(string)
lis
# Out:
# ['5-Year Swapnote']
