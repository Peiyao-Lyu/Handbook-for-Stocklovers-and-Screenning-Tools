# %%
import sft

# %%
sft.overview('aapl')
# Out:
# Apple Inc. designs, manufactures, and markets mobile communication and media devices, and personal computers. It also sells various related software, services, accessories, and third-party digital content and applications. The company offers iPhone, a line of smartphones; iPad, a line of multi-purpose tablets; and Mac, a line of desktop and portable personal computers, as well as iOS, macOS, watchOS, and tvOS operating systems. It also provides iTunes Store, an app store that allows customers to purchase and download, or stream music and TV shows; rent or purchase movies; and download free podcasts, as well as iCloud, a cloud service, which stores music, photos, contacts, calendars, mail, documents, and others. In addition, the company offers AppleCare support services; Apple Pay, a cashless payment service; Apple TV that connects to consumers' TVs and enables them to access digital content directly for streaming video, playing music and games, and viewing photos; and Apple Watch, a 
# ...

# %%
sft.governance('aapl')
# Out:
# Apple Inc.’s ISS Governance QualityScore as of November 1, 2018 is 1. The pillar scores are Audit: 1; Board: 2; Shareholder Rights: 1; Compensation: 6.

# %%
sft.summary('aapl')
# Out:
#                                                Value
# Index
# Previous Close                                179.55
# Open                                          180.29
# Bid                                    178.82 x 1100
# Ask                                     178.90 x 900
# Day's Range                          177.03 - 180.33
# 52 Week Range                        150.24 - 233.47
# Volume                                    39,531,549
# Avg. Volume                               38,567,290
# Market Cap                                  847.433B
# Beta (3Y Monthly)                               1.21
# PE Ratio (TTM)                                 14.99
# EPS (TTM)                                      11.91
# Earnings Date             Jan 30, 2019 - Feb 4, 2019
# Forward Dividend & Yield                2.92 (1.51%)
# Ex-Dividend Date                          2018-11-08
# 1y Target Est                                 231.32

# %%
sft.ratios('aapl')
# Out:
#                                    Value
# Finicial Ratio
# Profit Margin                     22.41%
# Operating Margin (ttm)            26.69%
# Return on Assets (ttm)            11.96%
# Return on Equity (ttm)            49.36%
# Revenue (ttm)                    265.59B
# Revenue Per Share (ttm)            53.60
# Quarterly Revenue Growth (yoy)    19.60%
# Gross Profit (ttm)               101.84B
# EBITDA                             81.8B
# Net Income Avi to Common (ttm)    59.53B
# Diluted EPS (ttm)                  11.91
# Quarterly Earnings Growth (yoy)   31.80%
# Total Cash (mrq)                   66.3B
# Total Cash Per Share (mrq)         13.97
# Total Debt (mrq)                 114.48B
# Total Debt/Equity (mrq)           106.85
# Current Ratio (mrq)                 1.12
# Book Value Per Share (mrq)         22.53
# Operating Cash Flow (ttm)         77.43B

# %%
sft.executives('aapl')
# Out:
#                                                  Title      Pay Exercised  \
# Name
# Mr. Timothy D. Cook                     CEO & Director      N/A       N/A
# Mr. Luca  Maestri                         CFO & Sr. VP      N/A       N/A
# Mr. Ron  Okamoto           Head of Developer Relations  147.42k       N/A
# Mr. Daniel J. Riccio    Sr. VP of Hardware Engineering      N/A       N/A
# Ms. Angela J. Ahrendts                Sr. VP of Retail      N/A       N/A
#
#                        Year Born
# Name
# Mr. Timothy D. Cook         1961
# Mr. Luca  Maestri           1964
# Mr. Ron  Okamoto             N/A
# Mr. Daniel J. Riccio        1963
# Ms. Angela J. Ahrendts      1961

# %%
sft.financial('aapl',IS=0,BS=1,CF=0)
# Out:
# ([                                     9/29/2018    9/30/2017    9/24/2016  \
#   Assets (All numbers in thousands)
#   Cash And Cash Equivalents           25,913,000   20,289,000   20,484,000
#   Short Term Investments              40,388,000   53,892,000   46,671,000
#   Net Receivables                     48,995,000   35,673,000   29,299,000
#   Inventory                            3,956,000    4,855,000    2,132,000
#   Other Current Assets                12,087,000   13,936,000    8,283,000
#   Total Current Assets               131,339,000  128,645,000  106,869,000
#   Long Term Investments              170,799,000  194,714,000  170,430,000
#   Property Plant and Equipment        41,304,000   33,783,000   27,010,000
#   Goodwill                                     -            -    5,414,000
#   Intangible Assets                            -            -    3,206,000
#   Accumulated Amortization                     -            -            -
# ...

# %%
sft.IS('aapl')
# Out:
#                                       9/29/2018    9/30/2017    9/24/2016  \
# Revenue (All numbers in thousands)
# Total Revenue                       265,595,000  229,234,000  215,639,000
# Cost of Revenue                     163,756,000  141,048,000  131,376,000
# Gross Profit                        101,839,000   88,186,000   84,263,000
#
#                                       9/26/2015
# Revenue (All numbers in thousands)
# Total Revenue                       233,715,000
# Cost of Revenue                     140,089,000
# Gross Profit                         93,626,000
#                                                  9/29/2018    9/30/2017  \
# Operating Expenses (All numbers in thousands)
# Research Development                            14,236,000   11,581,000
# Selling General and Administrative              16,705,000   15,261,000
# Non Recurring                                            -            -
# ...

# %%
sft.BS('aapl')
# Out:
#                                      9/29/2018    9/30/2017    9/24/2016  \
# Assets (All numbers in thousands)
# Cash And Cash Equivalents           25,913,000   20,289,000   20,484,000
# Short Term Investments              40,388,000   53,892,000   46,671,000
# Net Receivables                     48,995,000   35,673,000   29,299,000
# Inventory                            3,956,000    4,855,000    2,132,000
# Other Current Assets                12,087,000   13,936,000    8,283,000
# Total Current Assets               131,339,000  128,645,000  106,869,000
# Long Term Investments              170,799,000  194,714,000  170,430,000
# Property Plant and Equipment        41,304,000   33,783,000   27,010,000
# Goodwill                                     -            -    5,414,000
# Intangible Assets                            -            -    3,206,000
# Accumulated Amortization                     -            -            -
# ...

# %%
sft.CF('aapl')
# Out:
#                                         9/29/2018   9/30/2017   9/24/2016  \
# Net Income (All numbers in thousands)
# Net Income                             59,531,000  48,351,000  45,687,000
#
#                                         9/26/2015
# Net Income (All numbers in thousands)
# Net Income                             53,394,000
#                                                    9/29/2018   9/30/2017  \
# Operating Activities (All numbers in thousands)
# Depreciation                                      10,903,000  10,157,000
# Adjustments To Net Income                        -27,694,000  10,640,000
# Changes In Accounts Receivables                   -5,322,000  -2,093,000
# Changes In Liabilities                             9,131,000   8,340,000
# Changes In Inventories                               828,000  -2,723,000
# Changes In Other Operating Activities             30,057,000  -8,447,000
# Total Cash Flow From Operating Activities         77,434,000  64,225,000
#
# ...

# %%
sft.revenue('aapl')
# Out:
#                                       9/29/2018    9/30/2017    9/24/2016  \
# Revenue (All numbers in thousands)
# Total Revenue                       265,595,000  229,234,000  215,639,000
# Cost of Revenue                     163,756,000  141,048,000  131,376,000
# Gross Profit                        101,839,000   88,186,000   84,263,000
#
#                                       9/26/2015
# Revenue (All numbers in thousands)
# Total Revenue                       233,715,000
# Cost of Revenue                     140,089,000
# Gross Profit                         93,626,000

# %%
sft.operating_expenses('aapl')
# Out:
#                                                  9/29/2018    9/30/2017  \
# Operating Expenses (All numbers in thousands)
# Research Development                            14,236,000   11,581,000
# Selling General and Administrative              16,705,000   15,261,000
# Non Recurring                                            -            -
# Others                                                   -            -
# Total Operating Expenses                       194,697,000  167,890,000
# Operating Income or Loss                        70,898,000   61,344,000
#
#                                                  9/24/2016    9/26/2015
# Operating Expenses (All numbers in thousands)
# Research Development                            10,045,000    8,067,000
# Selling General and Administrative              14,194,000   14,329,000
# Non Recurring                                            -            -
# Others                                                   -            -
# ...

# %%
sft.operating_income('aapl')
# Out:
#                                                      9/29/2018   9/30/2017  \
# Income from Continuing Operations (All numbers ...
# Total Other Income/Expenses Net                      2,005,000   2,745,000
# Earnings Before Interest and Taxes                  70,898,000  61,344,000
# Interest Expense                                    -3,240,000  -2,323,000
# Income Before Tax                                   72,903,000  64,089,000
# Income Tax Expense                                  13,372,000  15,738,000
# Minority Interest                                            -           -
# Net Income From Continuing Ops                      59,531,000  48,351,000
#
#                                                      9/24/2016   9/26/2015
# Income from Continuing Operations (All numbers ...
# Total Other Income/Expenses Net                      1,348,000   1,285,000
# Earnings Before Interest and Taxes                  60,024,000  71,230,000
# ...

# %%
sft.non_recurring('aapl')
# Out:
#                                                 9/29/2018 9/30/2017 9/24/2016  \
# Non-recurring Events (All numbers in thousands)
# Discontinued Operations                                 -         -         -
# Extraordinary Items                                     -         -         -
# Effect Of Accounting Changes                            -         -         -
# Other Items                                             -         -         -
#
#                                                 9/26/2015
# Non-recurring Events (All numbers in thousands)
# Discontinued Operations                                 -
# Extraordinary Items                                     -
# Effect Of Accounting Changes                            -
# Other Items                                             -

# %%
sft.net_income('aapl')
# Out:
#                                          9/29/2018   9/30/2017   9/24/2016  \
# Net Income (All numbers in thousands)
# Net Income                              59,531,000  48,351,000  45,687,000
# Preferred Stock And Other Adjustments            -           -           -
# Net Income Applicable To Common Shares  59,531,000  48,351,000  45,687,000
#
#                                          9/26/2015
# Net Income (All numbers in thousands)
# Net Income                              53,394,000
# Preferred Stock And Other Adjustments            -
# Net Income Applicable To Common Shares  53,394,000

# %%
sft.assets('aapl')
# Out:
#                                      9/29/2018    9/30/2017    9/24/2016  \
# Assets (All numbers in thousands)
# Cash And Cash Equivalents           25,913,000   20,289,000   20,484,000
# Short Term Investments              40,388,000   53,892,000   46,671,000
# Net Receivables                     48,995,000   35,673,000   29,299,000
# Inventory                            3,956,000    4,855,000    2,132,000
# Other Current Assets                12,087,000   13,936,000    8,283,000
# Total Current Assets               131,339,000  128,645,000  106,869,000
# Long Term Investments              170,799,000  194,714,000  170,430,000
# Property Plant and Equipment        41,304,000   33,783,000   27,010,000
# Goodwill                                     -            -    5,414,000
# Intangible Assets                            -            -    3,206,000
# Accumulated Amortization                     -            -            -
# ...

# %%
sft.liabilities('aapl')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-34e872e36fe5> in <module>()
# ----> 1 sft.liabilities('aapl')
#
# ~\Desktop\sft.py in liabilities(ticker)
#     169
#     170 def liabilities(ticker):
# --> 171     return financial(ticker,BS=1)[1]['liabilities']
#     172
#     173 def equity(ticker):
#
# KeyError: 'liabilities'

# %%
sft.equity('aapl')
# Out:
#                                      9/29/2018    9/30/2017    9/24/2016  \
# Equity (All numbers in thousands)
# Misc. Stocks Options Warrants                -            -            -
# Redeemable Preferred Stock                   -            -            -
# Preferred Stock                              -            -            -
# Common Stock                        40,201,000   35,867,000   31,251,000
# Retained Earnings                   70,400,000   98,330,000   96,364,000
# Treasury Stock                      -3,454,000     -150,000      634,000
# Capital Surplus                              -            -            -
# Other Stockholder Equity            -3,454,000     -150,000      634,000
# Total Stockholder Equity           107,147,000  134,047,000  128,249,000
# Net Tangible Assets                107,147,000  134,047,000  119,629,000
#
#                                      9/26/2015
# Equity (All numbers in thousands)
# Misc. Stocks Options Warrants                -
# ...

# %%
sft.CFO('aapl')
# Out:
#                                                    9/29/2018   9/30/2017  \
# Operating Activities (All numbers in thousands)
# Depreciation                                      10,903,000  10,157,000
# Adjustments To Net Income                        -27,694,000  10,640,000
# Changes In Accounts Receivables                   -5,322,000  -2,093,000
# Changes In Liabilities                             9,131,000   8,340,000
# Changes In Inventories                               828,000  -2,723,000
# Changes In Other Operating Activities             30,057,000  -8,447,000
# Total Cash Flow From Operating Activities         77,434,000  64,225,000
#
#                                                   9/24/2016   9/26/2015
# Operating Activities (All numbers in thousands)
# Depreciation                                     10,505,000  11,257,000
# Adjustments To Net Income                         9,634,000   5,353,000
# ...

# %%
sft.CFI('aapl')
# Out:
#                                                    9/29/2018    9/30/2017  \
# Investing Activities (All numbers in thousands)
# Capital Expenditures                             -13,313,000  -12,451,000
# Investments                                       30,845,000  -33,542,000
# Other Cash flows from Investing Activities          -745,000     -124,000
# Total Cash Flows From Investing Activities        16,066,000  -46,446,000
#
#                                                    9/24/2016    9/26/2015
# Investing Activities (All numbers in thousands)
# Capital Expenditures                             -12,734,000  -11,247,000
# Investments                                      -32,022,000  -44,417,000
# Other Cash flows from Investing Activities          -924,000      -26,000
# Total Cash Flows From Investing Activities       -45,977,000  -56,274,000

# %%
sft.CFF('aapl')
# Out:
#                                                    9/29/2018    9/30/2017  \
# Financing Activities (All numbers in thousands)
# Dividends Paid                                   -13,712,000  -12,769,000
# Sale Purchase of Stock                                     -            -
# Net Borrowings                                       432,000   29,014,000
# Other Cash Flows from Financing Activities                 -            -
# Total Cash Flows From Financing Activities       -87,876,000  -17,974,000
#
#                                                    9/24/2016    9/26/2015
# Financing Activities (All numbers in thousands)
# Dividends Paid                                   -12,150,000  -11,561,000
# Sale Purchase of Stock                                     -            -
# Net Borrowings                                    22,057,000   29,305,000
# Other Cash Flows from Financing Activities                 -      749,000
# ...

# %%
sft.cash('aapl')
# Out:
#                                      9/29/2018 9/30/2017 9/24/2016  9/26/2015
# Cash (All numbers in thousands)
# Effect Of Exchange Rate Changes              -         -         -          -
# Change In Cash and Cash Equivalents  5,624,000  -195,000  -636,000  7,276,000

# %%
sft.complete_analysis('aapl')
# Out:
# ([                  Current Qtr. (Dec 2018) Next Qtr. (Mar 2019)  \
#   Earnings Estimate
#   No. of Analysts                        34                   33
#   Avg. Estimate                        4.72                 3.04
#   Low Estimate                         4.51                 2.41
#   High Estimate                        5.59                 3.39
#   Year Ago EPS                         3.89                 2.73
#
#                     Current Year (2019) Next Year (2020)
#   Earnings Estimate
#   No. of Analysts                    40               34
#   Avg. Estimate                   13.45            14.83
#   Low Estimate                    11.54            10.98
#   High Estimate                    15.4             18.5
#   Year Ago EPS                    11.91            13.45  ,
#                           Current Qtr. (Dec 2018) Next Qtr. (Mar 2019)  \
#   Revenue Estimate
#   No. of Analysts                              31                   31
# ...

# %%
sft.analysis('aapl')
# Out:
#                   Current Qtr. (Dec 2018) Next Qtr. (Mar 2019)  \
# Earnings Estimate
# No. of Analysts                        34                   33
# Avg. Estimate                        4.72                 3.04
# Low Estimate                         4.51                 2.41
# High Estimate                        5.59                 3.39
# Year Ago EPS                         3.89                 2.73
#
#                   Current Year (2019) Next Year (2020)
# Earnings Estimate
# No. of Analysts                    40               34
# Avg. Estimate                   13.45            14.83
# Low Estimate                    11.54            10.98
# High Estimate                    15.4             18.5
# Year Ago EPS                    11.91            13.45
#                         Current Qtr. (Dec 2018) Next Qtr. (Mar 2019)  \
# Revenue Estimate
# No. of Analysts                              31                   31
# ...

# %%
sft.est_earnings('aapl')
# Out:
#                   Current Qtr. (Dec 2018) Next Qtr. (Mar 2019)  \
# Earnings Estimate
# No. of Analysts                        34                   33
# Avg. Estimate                        4.72                 3.04
# Low Estimate                         4.51                 2.41
# High Estimate                        5.59                 3.39
# Year Ago EPS                         3.89                 2.73
#
#                   Current Year (2019) Next Year (2020)
# Earnings Estimate
# No. of Analysts                    40               34
# Avg. Estimate                   13.45            14.83
# Low Estimate                    11.54            10.98
# High Estimate                    15.4             18.5
# Year Ago EPS                    11.91            13.45

# %%
sft.est_revenue('aapl')
# Out:
#                         Current Qtr. (Dec 2018) Next Qtr. (Mar 2019)  \
# Revenue Estimate
# No. of Analysts                              31                   31
# Avg. Estimate                            91.88B               64.83B
# Low Estimate                             88.96B               59.99B
# High Estimate                           100.93B                67.3B
# Year Ago Sales                           88.29B               61.14B
# Sales Growth (year/est)                   4.10%                6.00%
#
#                         Current Year (2019) Next Year (2020)
# Revenue Estimate
# No. of Analysts                          37               31
# Avg. Estimate                       279.29B          291.14B
# Low Estimate                        269.23B          273.13B
# High Estimate                       292.33B          326.36B
# Year Ago Sales                       265.6B          279.29B
# Sales Growth (year/est)               5.20%            4.20%

# %%
sft.history_earnings('aapl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-4d1e2b7d113e> in <module>()
# ----> 1 sft.history_earnings('aapl')
#
# ~\Desktop\sft.py in history_earnings(ticker)
#     235
#     236 def history_earnings(ticker):
# --> 237     return self.complete_analysis(ticker)[1]['Earnings History']
#     238
#     239
#
# NameError: name 'self' is not defined

# %%
sft.EPS_trend('aapl')
# Out:
#                  Current Qtr. (Dec 2018) Next Qtr. (Mar 2019)  \
# EPS Trend
# Current Estimate                    4.72                 3.04
# 7 Days Ago                          4.74                 3.05
# 30 Days Ago                         4.94                 3.13
# 60 Days Ago                         4.92                 3.12
# 90 Days Ago                         4.87                 3.09
#
#                  Current Year (2019) Next Year (2020)
# EPS Trend
# Current Estimate               13.45            14.83
# 7 Days Ago                     13.48            14.82
# 30 Days Ago                    13.77            15.23
# 60 Days Ago                    13.71            15.08
# 90 Days Ago                    13.56            14.97

# %%
sft.EPS_revision('aapl')
# Out:
#                   Current Qtr. (Dec 2018) Next Qtr. (Mar 2019)  \
# EPS Revisions
# Up Last 7 Days                        N/A                  N/A
# Up Last 30 Days                         4                    5
# Down Last 7 Days                      N/A                  N/A
# Down Last 30 Days                       2                    3
#
#                   Current Year (2019) Next Year (2020)
# EPS Revisions
# Up Last 7 Days                    N/A              N/A
# Up Last 30 Days                     5                4
# Down Last 7 Days                  N/A              N/A
# Down Last 30 Days                   3              N/A

# %%
sft.est_growth('aapl')
# Out:
#                             AAPL Industry Sector S&P 500
# Growth Estimates
# Current Qtr.              21.30%      N/A    N/A    0.48
# Next Qtr.                 11.40%      N/A    N/A    0.40
# Current Year              12.90%      N/A    N/A    0.21
# Next Year                 10.30%      N/A    N/A    0.10
# Next 5 Years (per annum)  13.00%      N/A    N/A    0.11
# Past 5 Years (per annum)  11.72%      N/A    N/A     N/A

# %%
sft.holders_structure('aapl')
# Out:
# ([
#   Major Holders Breakdown
#   0.07%                          % of Shares Held by All Insider
#   61.16%                        % of Shares Held by Institutions
#   61.21%                         % of Float Held by Institutions
#   3,684                    Number of Institutions Holding Shares,
#                                             Shares Date Reported  % Out  \
#   Top Institutional Holders
#   Vanguard Group, Inc. (The)           347,890,172  Jun 29, 2018  7.20%
#   Blackrock Inc.                       311,719,812  Jun 29, 2018  6.45%
#   Berkshire Hathaway, Inc              251,955,877  Jun 29, 2018  5.22%
#   State Street Corporation             191,494,434  Jun 29, 2018  3.96%
#   FMR, LLC                             103,652,293  Jun 29, 2018  2.15%
#   Northern Trust Corporation            62,005,181  Jun 29, 2018  1.28%
#   Geode Capital Management, LLC         57,294,309  Jun 29, 2018  1.19%
# ...

# %%
sft.holders('aapl')
# Out:
#
# Major Holders Breakdown
# 0.07%                          % of Shares Held by All Insider
# 61.16%                        % of Shares Held by Institutions
# 61.21%                         % of Float Held by Institutions
# 3,684                    Number of Institutions Holding Shares
#                                           Shares Date Reported  % Out  \
# Top Institutional Holders
# Vanguard Group, Inc. (The)           347,890,172  Jun 29, 2018  7.20%
# Blackrock Inc.                       311,719,812  Jun 29, 2018  6.45%
# Berkshire Hathaway, Inc              251,955,877  Jun 29, 2018  5.22%
# State Street Corporation             191,494,434  Jun 29, 2018  3.96%
# FMR, LLC                             103,652,293  Jun 29, 2018  2.15%
# Northern Trust Corporation            62,005,181  Jun 29, 2018  1.28%
# Geode Capital Management, LLC         57,294,309  Jun 29, 2018  1.19%
# Norges Bank Investment Management     50,785,599  Dec 30, 2017  1.05%
# ...

# %%
sft.major_holders('aapl')
# Out:
#
# Major Holders Breakdown
# 0.07%                          % of Shares Held by All Insider
# 61.16%                        % of Shares Held by Institutions
# 61.21%                         % of Float Held by Institutions
# 3,684                    Number of Institutions Holding Shares

# %%
sft.ins_holders('aapl')
# Out:
#                                           Shares Date Reported  % Out  \
# Top Institutional Holders
# Vanguard Group, Inc. (The)           347,890,172  Jun 29, 2018  7.20%
# Blackrock Inc.                       311,719,812  Jun 29, 2018  6.45%
# Berkshire Hathaway, Inc              251,955,877  Jun 29, 2018  5.22%
# State Street Corporation             191,494,434  Jun 29, 2018  3.96%
# FMR, LLC                             103,652,293  Jun 29, 2018  2.15%
# Northern Trust Corporation            62,005,181  Jun 29, 2018  1.28%
# Geode Capital Management, LLC         57,294,309  Jun 29, 2018  1.19%
# Norges Bank Investment Management     50,785,599  Dec 30, 2017  1.05%
# Bank Of New York Mellon Corporation   49,427,723  Jun 29, 2018  1.02%
# Invesco Ltd.                          48,627,807  Jun 29, 2018  1.01%
#
#                                               Value
# Top Institutional Holders
# Vanguard Group, Inc. (The)           64,067,455,349
# ...

# %%
sft.mf_holders('aapl')
# Out:
#                                                          Shares Date Reported  \
# Top Mutual Fund Holders
# Vanguard Total Stock Market Index Fund              111,385,671  Dec 30, 2017
# Vanguard 500 Index Fund                              87,732,310  Dec 30, 2017
# SPDR S&P 500 ETF Trust                               54,866,536  Jun 29, 2018
# Vanguard Institutional Index Fund-Institutional...   51,998,552  Dec 30, 2017
# Invesco ETF Tr-Invesco QQQ Tr, Series 1 ETF          40,624,026  Jun 29, 2018
# Fidelity  500 Index Fund                             32,354,517  Jun 29, 2018
# iShares Core S&P 500 ETF                             31,649,842  Jun 29, 2018
# Vanguard Growth Index Fund                           31,115,219  Dec 30, 2017
# Select Sector SPDR Fund-Technology                   16,457,059  Jun 29, 2018
# iShares Russell 1000 Growth ETF                      16,218,061  Jun 29, 2018
#
#                                                     % Out           Value
# ...

# %%
sft.trading('aapl','2010-10-01','2010-11-01')
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2010-10-01  40.939999  40.192856  40.878571  40.360001  112035700  27.027594
# 2010-10-04  40.414288  39.681427  40.228573  39.805714  108825500  26.656401
# 2010-10-05  41.349998  40.259998  40.285713  41.277142  125491800  27.641764
# 2010-10-06  41.712856  40.751427  41.369999  41.312859  167717200  27.665682
# 2010-10-07  41.497143  40.987144  41.477142  41.317142  102099900  27.668552
# 2010-10-08  42.071430  41.428570  41.672855  42.009998  164600800  28.132532
# 2010-10-11  42.462856  42.085712  42.105713  42.194286  106938300  28.255941
# 2010-10-12  42.785713  41.784286  42.201427  42.648571  139636000  28.560163
# 2010-10-13  43.137142  42.828571  42.885715  42.877144  157523100  28.713224
# 2010-10-14  43.209999  42.914288  43.098572  43.187141  108824100  28.920822
# 2010-10-15  45.000000  43.558571  43.919998  44.962856  230548500  30.109943
# ...

# %%
sft.SMA('aapl','2010-10-01','2010-11-01',10)
# Out:
# Recomendation:
# The simple moving average startegy of window 10 yields a positive cumulative return. Hence, the strategy could be taken into consideration.
# (                 High        Low       Open      Close     Volume  Adj Close  \
#  Date
#  2010-10-01  40.939999  40.192856  40.878571  40.360001  112035700  27.027594
#  2010-10-04  40.414288  39.681427  40.228573  39.805714  108825500  26.656401
#  2010-10-05  41.349998  40.259998  40.285713  41.277142  125491800  27.641764
#  2010-10-06  41.712856  40.751427  41.369999  41.312859  167717200  27.665682
#  2010-10-07  41.497143  40.987144  41.477142  41.317142  102099900  27.668552
#  2010-10-08  42.071430  41.428570  41.672855  42.009998  164600800  28.132532
#  2010-10-11  42.462856  42.085712  42.105713  42.194286  106938300  28.255941
#  2010-10-12  42.785713  41.784286  42.201427  42.648571  139636000  28.560163
#  2010-10-13  43.137142  42.828571  42.885715  42.877144  157523100  28.713224
# ...

# %%
sft.EMA('aapl','2010-10-01','2010-11-01',10)
# Out:
# Recomendation:
# The exponential moving average startegy of window 10 yields a positive cumulative return. Hence, the strategy could be taken into consideration.
# (                 High        Low       Open      Close     Volume  Adj Close  \
#  Date
#  2010-10-01  40.939999  40.192856  40.878571  40.360001  112035700  27.027594
#  2010-10-04  40.414288  39.681427  40.228573  39.805714  108825500  26.656401
#  2010-10-05  41.349998  40.259998  40.285713  41.277142  125491800  27.641764
#  2010-10-06  41.712856  40.751427  41.369999  41.312859  167717200  27.665682
#  2010-10-07  41.497143  40.987144  41.477142  41.317142  102099900  27.668552
#  2010-10-08  42.071430  41.428570  41.672855  42.009998  164600800  28.132532
#  2010-10-11  42.462856  42.085712  42.105713  42.194286  106938300  28.255941
#  2010-10-12  42.785713  41.784286  42.201427  42.648571  139636000  28.560163
#  2010-10-13  43.137142  42.828571  42.885715  42.877144  157523100  28.713224
# ...

# %%
sft.MR('aapl','2010-10-01','2010-11-01',10,20)
# Out:
# (                 High        Low       Open      Close     Volume  Adj Close  \
#  Date
#  2010-10-01  40.939999  40.192856  40.878571  40.360001  112035700  27.027594
#  2010-10-04  40.414288  39.681427  40.228573  39.805714  108825500  26.656401
#  2010-10-05  41.349998  40.259998  40.285713  41.277142  125491800  27.641764
#  2010-10-06  41.712856  40.751427  41.369999  41.312859  167717200  27.665682
#  2010-10-07  41.497143  40.987144  41.477142  41.317142  102099900  27.668552
#  2010-10-08  42.071430  41.428570  41.672855  42.009998  164600800  28.132532
#  2010-10-11  42.462856  42.085712  42.105713  42.194286  106938300  28.255941
#  2010-10-12  42.785713  41.784286  42.201427  42.648571  139636000  28.560163
#  2010-10-13  43.137142  42.828571  42.885715  42.877144  157523100  28.713224
#  2010-10-14  43.209999  42.914288  43.098572  43.187141  108824100  28.920822
#  2010-10-15  45.000000  43.558571  43.919998  44.962856  230548500  30.109943
# ...

# %%
sft.RSI('aapl','2010-10-01','2010-11-01',10)
# Out:
# (                 High        Low       Open      Close     Volume  Adj Close  \
#  Date
#  2010-10-01  40.939999  40.192856  40.878571  40.360001  112035700  27.027594
#  2010-10-04  40.414288  39.681427  40.228573  39.805714  108825500  26.656401
#  2010-10-05  41.349998  40.259998  40.285713  41.277142  125491800  27.641764
#  2010-10-06  41.712856  40.751427  41.369999  41.312859  167717200  27.665682
#  2010-10-07  41.497143  40.987144  41.477142  41.317142  102099900  27.668552
#  2010-10-08  42.071430  41.428570  41.672855  42.009998  164600800  28.132532
#  2010-10-11  42.462856  42.085712  42.105713  42.194286  106938300  28.255941
#  2010-10-12  42.785713  41.784286  42.201427  42.648571  139636000  28.560163
#  2010-10-13  43.137142  42.828571  42.885715  42.877144  157523100  28.713224
#  2010-10-14  43.209999  42.914288  43.098572  43.187141  108824100  28.920822
#  2010-10-15  45.000000  43.558571  43.919998  44.962856  230548500  30.109943
# ...

# %%
sft.recommend('aapl','2010-10-01','2010-11-01')
# Out:
# Enter the window for Simple Moving Average strategy:
# 10
# Enter the window for Exponential Moving Average strategy:
# 12
# Enter the short window for Mean Reversion strategy:
# 12
# Enter the long window for Mean Reversion strategy:
# 12
# Enter the window for Relative Strength Index strategy:
# 12
# Recomendation:
# The simple moving average startegy of window 10 yields a positive cumulative return. Hence, the strategy could be taken into consideration.
# Recomendation:
# The exponential moving average startegy of window 12 yields a positive cumulative return. Hence, the strategy could be taken into consideration.
# Overall Recommendation: With given parameters input, we would recommend you Relative Strength Index strategy in this stock because it yields max return of 0.12 on historical data.
#      Cumulative Return
# SMA           0.015204
# EMA           0.025757
# MR            0.000000
# RSI           0.118302

# %%
sft.index()
# Out:
#                    Dow   Nasdaq   SP 500
# Current Data  25537.36  7330.74  2760.44
# Change         +199.62   +57.45   +22.41
# %Change           0.79     0.79     0.82

# %%
sft.industry()
# Out:
# Strong: Utilities, Health Care, Information Technology
# Weak: Energy, Communication Services, Materials

# %%
sft.market_news()
# Out:
# Moving the Market:
# G-20 Leaders Summit Underway; U.S. Trade Representative Robert Lighthizer said he would be surprised if dinner between President Trump and President Xi is not a successMarkets moves higher in recent trade following report that there are points of consensus between U.S. and China on trade; some disagreements remain Transportation stocks remain strong amid weakening oil pricesEnergy stocks underperform

# %%
sft.SNP('2010-10-01','2010-11-01')

# %%
sft.DJI('2010-10-01','2010-11-01')

# %%
sft.IXIC('2010-10-01','2010-11-01')

# %%
sft.best_performers(1)
# Out:
#                                   pct_change
# Daily Best Performing Stocks
# NorstraEnergyInc                     900.00%
# PetrosonicEnergyInc.                 200.00%
# WalterEnergyInc.                     166.67%
# PositiveidCorp                       100.00%
# SpoGlobalInc                         100.00%
# VetOnlineSupplyInc                   100.00%
# NorthBayResourcesInc                 100.00%
# AmericanGraphiteTechnologiesInc.      77.27%
# OnelifeTechnologiesCorp               75.00%
# FutureHealthcareOfAmerica             70.00%
# HarrisonVickers&WatermanInc           60.00%
# ProtokinetixInc.                      60.00%
# TelInstrumentElectronicsCorp          57.96%
# Plastic2oilInc.                       57.78%
# MobilesmithInc.                       54.17%
# DominovasEnergyCorp                   50.00%
# LingerieFightingChampionshipsInc.     50.00%
# PulseBeverageCorp                     50.00%
# AllAmericanGoldCorp.                  50.00%
# ...

# %%
sft.best_performers(6)
# Out:
# 'Wrong input!'

# %%
sft.major_index()
# Out:
#                                Last
# Major U.S. Stock Indexes
# DJIA                       25538.46
# DJ Transportation Average  10820.20
# DJ Utility Average           741.92
# DJ Total Stock Market      28418.59
# Barron's 400                 687.81
# Nasdaq Composite            7330.54
# Nasdaq 100                  6949.01
# S&P 500                     2760.17
# S&P MidCap 400              1878.65
# S&P SmallCap 600             962.95
# Russell 2000                1533.27
# NYSE Composite             12457.55
# NYSE Arca Biotech           4755.55
# NYSE Arca Pharma             609.15
# KBW Bank                     101.57
# PHLX Gold/Silver              64.46
# PHLX Oil Service             104.74
# PHLX Semiconductor          1239.60
# CBOE Volatility               18.07

# %%
sft.forex()
# Out:
#                Dollar    Euro   Pound     Yen     Yuan
# Dollar U.S.        --  1.1357  1.2775  0.0088   0.1436
# Euro Europe    0.8802      --  1.1245  0.0077   0.1264
# Pound Britain  0.7827  0.8889      --  0.0069   0.1124
# Yen Japan      113.81  129.25  145.39      --  16.3398
# Yuan China     6.9558  7.8997   8.886  0.0611       --

# %%
sft.futures()
# Out:
#                                                Last   Change  Change %
# Futures Contract Names
# 10-Year Euro Bund                           €161.48    +0.07    +0.04%
# 10-Year Swapnote                            €149.18    +0.06    +0.04%
# 10-Year Treasury Notes                      $119.67    +0.36    +0.30%
# 1-Month Libor                                $97.62     0.00     0.00%
# 2-Year Euro Schatz                          €112.00    -0.01  -0.0089%
# 2-Year Treasury Notes                       $105.54    +0.05    +0.05%
# 30-Day Federal Funds                         $97.61  +0.0050  +0.0051%
# 30-Year Treasury Notes                      $140.28    +0.78    +0.56%
# 3-Month Euribor                             €100.27     0.00     0.00%
# 3-Month Euro Dollar                          $97.00    +0.03    +0.03%
# 3-Month Euroswiss                         CHF100.70    -0.01  -0.0099%
# 5-Year Euro Bob                             €131.93     0.00     0.00%
# ...

# %%
sft.history_earnings('aapl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-4d1e2b7d113e> in <module>()
# ----> 1 sft.history_earnings('aapl')
#
# ~\Desktop\sft.py in history_earnings(ticker)
#     235
#     236 def history_earnings(ticker):
# --> 237     return complete_analysis(ticker)[1]['Earnings History']
#     238
#     239
#
# NameError: name 'self' is not defined

# %%
sft.liabilities('aapl')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-34e872e36fe5> in <module>()
# ----> 1 sft.liabilities('aapl')
#
# ~\Desktop\sft.py in liabilities(ticker)
#     169
#     170 def liabilities(ticker):
# --> 171     return financial(ticker,BS=1)[1]['Liabilities']
#     172
#     173 def equity(ticker):
#
# KeyError: 'liabilities'
